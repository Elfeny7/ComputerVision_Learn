# %% [markdown]
# <a href="https://colab.research.google.com/github/Elfeny7/PCVK_Sem5/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ikmal Faris Musyaffa / 2141720123 / 12 / 3B
#
# PCVK Minggu1

# %% [markdown]
# **Step1**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# **Step2**

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **Step3**

# %%
height = image_2.shape[0]
width = image_2.shape[1]
print("Resolusi Image : ")
print("\n", height, " x ", width)
cv2_imshow(image_2)
# Out:
# Resolusi Image :
#
#  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# **Step4**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#membuat garis horizontal ditengah image
for y in range (width):
  image_3[int((height)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# Jawab : **Agar lebih mudah dan tidak perlu menginstall tools-tools dan agar bisa langsung terhubung dengan github**
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawab :
#
# **numpy as np:**
#
# Modul numpy adalah pustaka dasar untuk komputasi numerik dalam bahasa pemrograman Python.
# Biasanya digunakan untuk operasi matriks, array, dan komputasi numerik lainnya.
# Alias np digunakan untuk mempermudah penulisan kode.
#
# **pandas as pd:**
#
# Modul pandas digunakan untuk analisis dan manipulasi data tabular, seperti data dalam format DataFrame.
# Ini sering digunakan dalam pengolahan dan analisis data.
#
# **cv2 as cv:**
#
# Modul cv2 (OpenCV) adalah pustaka pengolahan gambar dan komputer vision yang kuat.
# Digunakan untuk membaca, memanipulasi, dan menganalisis gambar dan video.
# Biasanya digunakan dalam aplikasi pengolahan gambar dan visi komputer.
# from google.colab.patches import
#
# **cv2_imshow:**
#
# Modul ini digunakan untuk menampilkan gambar dalam Colab Notebook.
# cv2_imshow adalah fungsi yang memungkinkan tampilan gambar langsung dalam notebook.
#
# **from skimage import io:**
#
# Modul io dari scikit-image digunakan untuk membaca dan menulis gambar dari berbagai format.
# Berguna ketika Anda perlu memuat gambar untuk diproses menggunakan berbagai algoritma pemrosesan gambar.
#
# **from skimage import transform:**
#
# Modul transform dari scikit-image berisi fungsi-fungsi untuk transformasi geometris pada gambar.
# Dapat digunakan untuk memutar, memotong, dan melakukan operasi transformasi lainnya pada gambar.
#
# **from PIL import Image:**
#
# Modul Image dari Python Imaging Library (PIL) digunakan untuk manipulasi gambar.
# Ini berguna ketika Anda perlu membuka, menyimpan, dan memanipulasi gambar dalam berbagai format.
#
# **import matplotlib.pylab as plt:**
#
# Modul pylab dari matplotlib digunakan untuk visualisasi data.
# plt adalah alias yang umum digunakan untuk mempermudah pembuatan grafik dan plot dalam kode.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# Jawab :
#
# **Untuk mengubah ukuran gambar menjadi setengan dari gambar asli, jika tidak dilakukan maka gmabar akan menjadi terlalu besar atau sama seperti ukuran aslinya.**
#
# 4. Perhatikan potongan kode progam berikut :
# for y in range (width):
#   image_3[int((height)/2),y] = [255,255,255]
#  Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab :
# **Untuk mewarnai garis menjadi warna putih**
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
# Jawab :
#
# **Resolusi gambar yang tinggi mempunyai pixel yang banyak sedangkan resolusi rendah mempunyai pixel yang sedikit, misal gambar dengan resolusi 1mp (mega pixel) mempunyai 1 juta pixel pada 1 gambarnya.**

# %% [markdown]
# ### **Tugas**
#
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (height):
  image_3[y, int((width)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0,0), (width,height), (255,255,255), 2)
cv.line(image_3, (width, 0), (0, height), (255, 255, 255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (140,145):
  for y in range (220,270):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (220,270):
  for x in range(120,160):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ### **TUGAS KELOMPOK**

# %%
from google.colab import drive
drive.mount('/content/drive')
ktp = cv.imread('/content/drive/MyDrive/PCVK/Images/ktp.jpeg')
ktprgb = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)

for x in range(70, 110):
    for y in range(220, 600):
        ktprgb[x, y] = [255, 255, 0]

ktprgb2 = ktprgb.copy()

for x in range(130, 150):
    for y in range(220, 470):
        ktprgb2[x, y] = [255, 0, 0]

plt.imshow(ktprgb2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
